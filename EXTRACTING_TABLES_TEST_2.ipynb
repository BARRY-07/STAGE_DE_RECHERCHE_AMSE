# %%
### Test du code sur un pdf simple contenant 3 tableaux avec le module TABULA

# %%
import tabula

pdf_path="6 Bulletin full2017_compressed.pdf"

dfs=tabula.read_pdf(pdf_path,pages='39',stream=True)

for i in range(len(dfs)):
    dfs[i].to_csv(f"all_pages_table_mariages{i}.csv")
# Out:
# Got stderr: mai 11, 2022 4:38:18 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# AVERTISSEMENT: New fonts found, font cache will be re-built
# mai 11, 2022 4:38:18 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# AVERTISSEMENT: Building on-disk font cache, this may take a while
# mai 11, 2022 4:38:22 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# AVERTISSEMENT: Finished building on-disk font cache, found 637 fonts

# %%
import pandas as pd

df1 = pd.read_csv('all_pages_table_mariages0.csv',index_col=0)

# %%
df1
# Out:
#     Unnamed: 0.1               Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 0            NaN                      NaN             NaN        NaN
# 1            NaN                      NaN             NaN        NaN
# 2   Governorates                      NaN  Kessm \ Markze        NaN
# 3            NaN                      NaN             NaN        NaN
# 4            NaN                      NaN             NaN        NaN
# 5            NaN                      NaN             NaN        NaN
# 6            NaN                      NaN             NaN      Urban
# 7            NaN                    Total             NaN      Rural
# 8            NaN                      NaN             NaN      Total
# 9            NaN          Kessm El_Tebeen             NaN        NaN
# 10           NaN             Kessm Helwan             NaN        NaN
# 11           NaN       Kessm EL_ Maassara             NaN        NaN
# 12           NaN             Kessm 15 May             NaN        NaN
# ...
