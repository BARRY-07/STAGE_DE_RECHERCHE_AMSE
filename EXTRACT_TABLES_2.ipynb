# %%
import camelot.io as camelot

# %%
tables=camelot.read_pdf("ast_sci_data_tables_sample.pdf",pages='all')

# %%
for i in range(len(tables)):
    tables[i].to_csv(f"all_pages_table{i}.csv")

# %%
import pandas as pd

# %%
df0=pd.read_csv("all_pages_table0.csv",index_col=0)
df1=pd.read_csv("all_pages_table1.csv",index_col=0)
df2=pd.read_csv("all_pages_table2.csv",index_col=0)

# %%
df0
# Out:
#                                               Unnamed: 1
# Number of Coils         Number of Paperclips
# 5                                                3, 5, 4
# 10                                               7, 8, 6
# 15                                            11, 10, 12
# 20                                            15, 13, 14

# %%
df1
# Out:
#                       Driver                         Car         Engine\nDate  \
# Speed (mph)
# 407.447      Craig Breedlove           Spirit of America       GE J47\n8/5/63
# 413.199            Tom Green            Wingfoot Express    WE J46  \n10/2/64
# 434.220           Art Arfons               Green Monster     GE J79 \n10/5/64
# 468.719      Craig Breedlove           Spirit of America    GE J79 \n10/13/64
# 526.277      Craig Breedlove           Spirit of America    GE J79 \n10/15/65
# 536.712           Art Arfons               Green Monster   GE J79  \n10/27/65
# 555.127      Craig Breedlove  Spirit of America, Sonic 1     GE J79 \n11/2/65
# 576.553           Art Arfons               Green Monster     GE J79 \n11/7/65
# 600.601      Craig Breedlove  Spirit of America, Sonic 1    GE J79 \n11/15/65
# 622.407        Gary Gabelich                  Blue Flame    Rocket \n10/23/70
# 633.468        Richard Noble                    Thrust 2  RR RG 146 \n10/4/83
# ...

# %%
df2
# Out:
#                                                   Unnamed: 1
# Time (drops of water)           Distance (cm)
# 1                                                    10,11,9
# 2                                                 29, 31, 30
# 3                                                 59, 58, 61
# 4                                               102, 100, 98
# 5                                              122, 125, 127
